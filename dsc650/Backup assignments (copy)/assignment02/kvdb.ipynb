# %%
import json
from pathlib import Path
import os

import pandas as pd
import s3fs


def read_cluster_csv(file_path, endpoint_url='https://storage.budsc.midwest-datascience.com'):
    s3 = s3fs.S3FileSystem(
        anon=True,
        client_kwargs={
            'endpoint_url': endpoint_url
        }
    )
    return pd.read_csv(s3.open(file_path, mode='rb'))

current_dir = Path(os.getcwd()).absolute()
results_dir = current_dir.joinpath('results')
kv_data_dir = results_dir.joinpath('kvdb')
kv_data_dir.mkdir(parents=True, exist_ok=True)

people_json = kv_data_dir.joinpath('people.json')
visited_json = kv_data_dir.joinpath('visited.json')
sites_json = kv_data_dir.joinpath('sites.json')
measurements_json = kv_data_dir.joinpath('measurements.json')

# %%
class KVDB(object):
    def __init__(self, db_path):
        self._db_path = Path(db_path)
        self._db = {}
        self._load_db()

    def _load_db(self):
        if self._db_path.exists():
            with open(self._db_path) as f:
                self._db = json.load(f)

    def get_value(self, key):
        return self._db.get(key)

    def set_value(self, key, value):
        self._db[key] = value

    def save(self):
        with open(self._db_path, 'w') as f:
            json.dump(self._db, f, indent=2)

# %%
def create_sites_kvdb():
    db = KVDB(sites_json)
    df = read_cluster_csv('data/external/tidynomicon/site.csv')
    for site_id, group_df in df.groupby('site_id'):
        db.set_value(site_id, group_df.to_dict(orient='records')[0])
    db.save()


def create_people_kvdb():
    db = KVDB(people_json)
    df = read_cluster_csv('data/external/tidynomicon/person.csv')
    for person_id, group_df in df.groupby('person_id'):
        db.set_value(person_id, group_df.to_dict(orient='records')[0])
    db.save()


def create_visits_kvdb():
    db = KVDB(visited_json)
    ## TODO: Implement code
    db.save()


def create_measurements_kvdb():
    db = KVDB(measurements_json)
    ## TODO: Implement code
    db.save()

# %%
create_sites_kvdb()
create_people_kvdb()
create_visits_kvdb()
create_measurements_kvdb()
# Out:
# ---------------------------------------------------------------------------
# ServerTimeoutError                        Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-4-dbc8e5b585b0> in <module>
# ----> 1 create_sites_kvdb()
#       2 create_people_kvdb()
#       3 create_visits_kvdb()
#
# <ipython-input-3-a552e36649aa> in create_sites_kvdb()
#       2     db = KVDB(sites_json)
# ----> 3     df = read_cluster_csv('data/external/tidynomicon/site.csv')
#       4     for site_id, group_df in df.groupby('site_id'):
#
# <ipython-input-1-f763f7c5920a> in read_cluster_csv(file_path, endpoint_url)
#      15     )
# ---> 16     return pd.read_csv(s3.open(file_path, mode='rb'))
#      17
#
# ~/venv/lib/python3.8/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     936             ac = kwargs.pop("autocommit", not self._intrans)
# --> 937             f = self._open(
#     938                 path,
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     470
# --> 471         return S3File(
#     472             self,
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#    1561                 self.version_id = self.details.get("VersionId")
# -> 1562         super().__init__(
#    1563             s3, path, mode, block_size, autocommit=autocommit, cache_type=cache_type
#
# ~/venv/lib/python3.8/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, **kwargs)
#    1264             if not hasattr(self, "details"):
# -> 1265                 self.details = fs.info(path)
#    1266             self.size = self.details["size"]
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in info(self, path, version_id, refresh)
#     924         if should_fetch_from_s3:
# --> 925             return maybe_sync(self._info, self, path, bucket, key, kwargs, version_id)
#     926         return super().info(path)
#
# ~/venv/lib/python3.8/site-packages/fsspec/asyn.py in maybe_sync(func, self, *args, **kwargs)
#      99             # run the awaitable on the loop
# --> 100             return sync(loop, func, *args, **kwargs)
#     101         else:
#
# ~/venv/lib/python3.8/site-packages/fsspec/asyn.py in sync(loop, func, callback_timeout, *args, **kwargs)
#      70         typ, exc, tb = error[0]
# ---> 71         raise exc.with_traceback(tb)
#      72     else:
#
# ~/venv/lib/python3.8/site-packages/fsspec/asyn.py in f()
#      54                 future = asyncio.wait_for(future, callback_timeout)
# ---> 55             result[0] = await future
#      56         except Exception:
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in _info(self, path, bucket, key, kwargs, version_id)
#     856         try:
# --> 857             out = await self._call_s3(
#     858                 self.s3.head_object,
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     251                 err = e
# --> 252         raise translate_boto_error(err) from err
#     253
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     233             try:
# --> 234                 return await method(**additional_kwargs)
#     235             except S3_RETRYABLE_ERRORS as e:
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     139         else:
# --> 140             http, parsed_response = await self._make_request(
#     141                 operation_model, request_dict, request_context)
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     159         try:
# --> 160             return await self._endpoint.make_request(operation_model, request_dict)
#     161         except Exception as e:
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/endpoint.py in _send_request(self, request_dict, operation_model)
#      88             request, operation_model, context)
# ---> 89         while await self._needs_retry(attempts, operation_model,
#      90                                       request_dict, success_response,
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/endpoint.py in _needs_retry(self, attempts, operation_model, request_dict, response, caught_exception)
#     196             operation_model.name)
# --> 197         responses = await self._event_emitter.emit(
#     198             event_name, response=response, endpoint=self,
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#      28             else:
# ---> 29                 response = handler(**kwargs)
#      30
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in __call__(self, attempts, response, caught_exception, **kwargs)
#     182         """
# --> 183         if self._checker(attempts, response, caught_exception):
#     184             result = self._action(attempts=attempts)
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     249     def __call__(self, attempt_number, response, caught_exception):
# --> 250         should_retry = self._should_retry(attempt_number, response,
#     251                                           caught_exception)
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in _should_retry(self, attempt_number, response, caught_exception)
#     276             # propogate if one has occurred.
# --> 277             return self._checker(attempt_number, response, caught_exception)
#     278
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     315         for checker in self._checkers:
# --> 316             checker_response = checker(attempt_number, response,
#     317                                        caught_exception)
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     221         elif caught_exception is not None:
# --> 222             return self._check_caught_exception(
#     223                 attempt_number, caught_exception)
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in _check_caught_exception(self, attempt_number, caught_exception)
#     358         # then this exception just propogates out past the retry code.
# --> 359         raise caught_exception
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/endpoint.py in _do_get_response(self, request, operation_model)
#     155             if http_response is None:
# --> 156                 http_response = await self._send(request)
#     157         except aiohttp.ClientConnectionError as e:
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/endpoint.py in _send(self, request)
#     240         url = URL(url, encoded=True)
# --> 241         resp = await self.http_session.request(
#     242             request.method, url=url, headers=headers_, data=data, proxy=proxy)
#
# ~/venv/lib/python3.8/site-packages/aiohttp/client.py in _request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, proxy_headers, trace_request_ctx, read_bufsize)
#     523                     except asyncio.TimeoutError as exc:
# --> 524                         raise ServerTimeoutError(
#     525                             "Connection timeout " "to host {}".format(url)
#
# ServerTimeoutError: Connection timeout to host https://storage.budsc.midwest-datascience.com/data/external/tidynomicon/site.csv
#
# The above exception was the direct cause of the following exception:
#
# ServerTimeoutError                        Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-4-dbc8e5b585b0> in <module>
# ----> 1 create_sites_kvdb()
#       2 create_people_kvdb()
#       3 create_visits_kvdb()
#
# <ipython-input-3-a552e36649aa> in create_sites_kvdb()
#       2     db = KVDB(sites_json)
# ----> 3     df = read_cluster_csv('data/external/tidynomicon/site.csv')
#       4     for site_id, group_df in df.groupby('site_id'):
#
# <ipython-input-1-f763f7c5920a> in read_cluster_csv(file_path, endpoint_url)
#      15     )
# ---> 16     return pd.read_csv(s3.open(file_path, mode='rb'))
#      17
#
# ~/venv/lib/python3.8/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     936             ac = kwargs.pop("autocommit", not self._intrans)
# --> 937             f = self._open(
#     938                 path,
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     470
# --> 471         return S3File(
#     472             self,
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#    1561                 self.version_id = self.details.get("VersionId")
# -> 1562         super().__init__(
#    1563             s3, path, mode, block_size, autocommit=autocommit, cache_type=cache_type
#
# ~/venv/lib/python3.8/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, **kwargs)
#    1264             if not hasattr(self, "details"):
# -> 1265                 self.details = fs.info(path)
#    1266             self.size = self.details["size"]
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in info(self, path, version_id, refresh)
#     924         if should_fetch_from_s3:
# --> 925             return maybe_sync(self._info, self, path, bucket, key, kwargs, version_id)
#     926         return super().info(path)
#
# ~/venv/lib/python3.8/site-packages/fsspec/asyn.py in maybe_sync(func, self, *args, **kwargs)
#      99             # run the awaitable on the loop
# --> 100             return sync(loop, func, *args, **kwargs)
#     101         else:
#
# ~/venv/lib/python3.8/site-packages/fsspec/asyn.py in sync(loop, func, callback_timeout, *args, **kwargs)
#      70         typ, exc, tb = error[0]
# ---> 71         raise exc.with_traceback(tb)
#      72     else:
#
# ~/venv/lib/python3.8/site-packages/fsspec/asyn.py in f()
#      54                 future = asyncio.wait_for(future, callback_timeout)
# ---> 55             result[0] = await future
#      56         except Exception:
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in _info(self, path, bucket, key, kwargs, version_id)
#     856         try:
# --> 857             out = await self._call_s3(
#     858                 self.s3.head_object,
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     251                 err = e
# --> 252         raise translate_boto_error(err) from err
#     253
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     233             try:
# --> 234                 return await method(**additional_kwargs)
#     235             except S3_RETRYABLE_ERRORS as e:
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     139         else:
# --> 140             http, parsed_response = await self._make_request(
#     141                 operation_model, request_dict, request_context)
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     159         try:
# --> 160             return await self._endpoint.make_request(operation_model, request_dict)
#     161         except Exception as e:
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/endpoint.py in _send_request(self, request_dict, operation_model)
#      88             request, operation_model, context)
# ---> 89         while await self._needs_retry(attempts, operation_model,
#      90                                       request_dict, success_response,
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/endpoint.py in _needs_retry(self, attempts, operation_model, request_dict, response, caught_exception)
#     196             operation_model.name)
# --> 197         responses = await self._event_emitter.emit(
#     198             event_name, response=response, endpoint=self,
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#      28             else:
# ---> 29                 response = handler(**kwargs)
#      30
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in __call__(self, attempts, response, caught_exception, **kwargs)
#     182         """
# --> 183         if self._checker(attempts, response, caught_exception):
#     184             result = self._action(attempts=attempts)
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     249     def __call__(self, attempt_number, response, caught_exception):
# --> 250         should_retry = self._should_retry(attempt_number, response,
#     251                                           caught_exception)
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in _should_retry(self, attempt_number, response, caught_exception)
#     276             # propogate if one has occurred.
# --> 277             return self._checker(attempt_number, response, caught_exception)
#     278
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     315         for checker in self._checkers:
# --> 316             checker_response = checker(attempt_number, response,
#     317                                        caught_exception)
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     221         elif caught_exception is not None:
# --> 222             return self._check_caught_exception(
#     223                 attempt_number, caught_exception)
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in _check_caught_exception(self, attempt_number, caught_exception)
#     358         # then this exception just propogates out past the retry code.
# --> 359         raise caught_exception
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/endpoint.py in _do_get_response(self, request, operation_model)
#     155             if http_response is None:
# --> 156                 http_response = await self._send(request)
#     157         except aiohttp.ClientConnectionError as e:
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/endpoint.py in _send(self, request)
#     240         url = URL(url, encoded=True)
# --> 241         resp = await self.http_session.request(
#     242             request.method, url=url, headers=headers_, data=data, proxy=proxy)
#
# ~/venv/lib/python3.8/site-packages/aiohttp/client.py in _request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, proxy_headers, trace_request_ctx, read_bufsize)
#     523                     except asyncio.TimeoutError as exc:
# --> 524                         raise ServerTimeoutError(
#     525                             "Connection timeout " "to host {}".format(url)
#
# ServerTimeoutError: Connection timeout to host https://storage.budsc.midwest-datascience.com/data/external/tidynomicon/site.csv
#
# The above exception was the direct cause of the following exception:
#
# ServerTimeoutError                        Traceback (most recent call last)
# <ipython-input-4-dbc8e5b585b0> in <module>
# ----> 1 create_sites_kvdb()
#       2 create_people_kvdb()
#       3 create_visits_kvdb()
#       4 create_measurements_kvdb()
#
# <ipython-input-3-a552e36649aa> in create_sites_kvdb()
#       1 def create_sites_kvdb():
#       2     db = KVDB(sites_json)
# ----> 3     df = read_cluster_csv('data/external/tidynomicon/site.csv')
#       4     for site_id, group_df in df.groupby('site_id'):
#       5         db.set_value(site_id, group_df.to_dict(orient='records')[0])
#
# <ipython-input-1-f763f7c5920a> in read_cluster_csv(file_path, endpoint_url)
#      14         }
#      15     )
# ---> 16     return pd.read_csv(s3.open(file_path, mode='rb'))
#      17
#      18 current_dir = Path(os.getcwd()).absolute()
#
# ~/venv/lib/python3.8/site-packages/fsspec/spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     935         else:
#     936             ac = kwargs.pop("autocommit", not self._intrans)
# --> 937             f = self._open(
#     938                 path,
#     939                 mode=mode,
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     469             cache_type = self.default_cache_type
#     470
# --> 471         return S3File(
#     472             self,
#     473             path,
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#    1560                 self.details = s3.info(path)
#    1561                 self.version_id = self.details.get("VersionId")
# -> 1562         super().__init__(
#    1563             s3, path, mode, block_size, autocommit=autocommit, cache_type=cache_type
#    1564         )
#
# ~/venv/lib/python3.8/site-packages/fsspec/spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, **kwargs)
#    1263         if mode == "rb":
#    1264             if not hasattr(self, "details"):
# -> 1265                 self.details = fs.info(path)
#    1266             self.size = self.details["size"]
#    1267             self.cache = caches[cache_type](
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in info(self, path, version_id, refresh)
#     923
#     924         if should_fetch_from_s3:
# --> 925             return maybe_sync(self._info, self, path, bucket, key, kwargs, version_id)
#     926         return super().info(path)
#     927
#
# ~/venv/lib/python3.8/site-packages/fsspec/asyn.py in maybe_sync(func, self, *args, **kwargs)
#      98         if inspect.iscoroutinefunction(func):
#      99             # run the awaitable on the loop
# --> 100             return sync(loop, func, *args, **kwargs)
#     101         else:
#     102             # just call the blocking function
#
# ~/venv/lib/python3.8/site-packages/fsspec/asyn.py in sync(loop, func, callback_timeout, *args, **kwargs)
#      69     if error[0]:
#      70         typ, exc, tb = error[0]
# ---> 71         raise exc.with_traceback(tb)
#      72     else:
#      73         return result[0]
#
# ~/venv/lib/python3.8/site-packages/fsspec/asyn.py in f()
#      53             if callback_timeout is not None:
#      54                 future = asyncio.wait_for(future, callback_timeout)
# ---> 55             result[0] = await future
#      56         except Exception:
#      57             error[0] = sys.exc_info()
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in _info(self, path, bucket, key, kwargs, version_id)
#     855             bucket, key, version_id = self.split_path(path)
#     856         try:
# --> 857             out = await self._call_s3(
#     858                 self.s3.head_object,
#     859                 kwargs,
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     250             except Exception as e:
#     251                 err = e
# --> 252         raise translate_boto_error(err) from err
#     253
#     254     call_s3 = sync_wrapper(_call_s3)
#
# ~/venv/lib/python3.8/site-packages/s3fs/core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     232         for i in range(self.retries):
#     233             try:
# --> 234                 return await method(**additional_kwargs)
#     235             except S3_RETRYABLE_ERRORS as e:
#     236                 logger.debug("Retryable error: %s" % e)
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/client.py in _make_api_call(self, operation_name, api_params)
#     138             http, parsed_response = event_response
#     139         else:
# --> 140             http, parsed_response = await self._make_request(
#     141                 operation_model, request_dict, request_context)
#     142
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     158     async def _make_request(self, operation_model, request_dict, request_context):
#     159         try:
# --> 160             return await self._endpoint.make_request(operation_model, request_dict)
#     161         except Exception as e:
#     162             await self.meta.events.emit(
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/endpoint.py in _send_request(self, request_dict, operation_model)
#      87         success_response, exception = await self._get_response(
#      88             request, operation_model, context)
# ---> 89         while await self._needs_retry(attempts, operation_model,
#      90                                       request_dict, success_response,
#      91                                       exception):
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/endpoint.py in _needs_retry(self, attempts, operation_model, request_dict, response, caught_exception)
#     195             service_id,
#     196             operation_model.name)
# --> 197         responses = await self._event_emitter.emit(
#     198             event_name, response=response, endpoint=self,
#     199             operation=operation_model, attempts=attempts,
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#      27                 response = await handler(**kwargs)
#      28             else:
# ---> 29                 response = handler(**kwargs)
#      30
#      31             responses.append((handler, response))
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in __call__(self, attempts, response, caught_exception, **kwargs)
#     181
#     182         """
# --> 183         if self._checker(attempts, response, caught_exception):
#     184             result = self._action(attempts=attempts)
#     185             logger.debug("Retry needed, action of: %s", result)
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     248
#     249     def __call__(self, attempt_number, response, caught_exception):
# --> 250         should_retry = self._should_retry(attempt_number, response,
#     251                                           caught_exception)
#     252         if should_retry:
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in _should_retry(self, attempt_number, response, caught_exception)
#     275             # If we've exceeded the max attempts we just let the exception
#     276             # propogate if one has occurred.
# --> 277             return self._checker(attempt_number, response, caught_exception)
#     278
#     279
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     314     def __call__(self, attempt_number, response, caught_exception):
#     315         for checker in self._checkers:
# --> 316             checker_response = checker(attempt_number, response,
#     317                                        caught_exception)
#     318             if checker_response:
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     220             return self._check_response(attempt_number, response)
#     221         elif caught_exception is not None:
# --> 222             return self._check_caught_exception(
#     223                 attempt_number, caught_exception)
#     224         else:
#
# ~/venv/lib/python3.8/site-packages/botocore/retryhandler.py in _check_caught_exception(self, attempt_number, caught_exception)
#     357         # the MaxAttemptsDecorator is not interested in retrying the exception
#     358         # then this exception just propogates out past the retry code.
# --> 359         raise caught_exception
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/endpoint.py in _do_get_response(self, request, operation_model)
#     154             http_response = first_non_none_response(responses)
#     155             if http_response is None:
# --> 156                 http_response = await self._send(request)
#     157         except aiohttp.ClientConnectionError as e:
#     158             e.request = request  # botocore expects the request property
#
# ~/venv/lib/python3.8/site-packages/aiobotocore/endpoint.py in _send(self, request)
#     239
#     240         url = URL(url, encoded=True)
# --> 241         resp = await self.http_session.request(
#     242             request.method, url=url, headers=headers_, data=data, proxy=proxy)
#     243
#
# ~/venv/lib/python3.8/site-packages/aiohttp/client.py in _request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, proxy_headers, trace_request_ctx, read_bufsize)
#     522                             )
#     523                     except asyncio.TimeoutError as exc:
# --> 524                         raise ServerTimeoutError(
#     525                             "Connection timeout " "to host {}".format(url)
#     526                         ) from exc
#
# ServerTimeoutError: Connection timeout to host https://storage.budsc.midwest-datascience.com/data/external/tidynomicon/site.csv
